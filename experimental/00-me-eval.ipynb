# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
data=Path(r'C:\Users\Mathias\repos\habitual_errors_NLP\results\MJFF\char_time\Enlish_attempt1_talos_best_model_2020-04-01_14-19-07\EnglishData-preprocessed_attempt_1')

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt

lw = 3
plt.figure(figsize = (5,5))
plt.axis('equal')
plt.grid(True, alpha = 0.3)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
AUC = []
interp_tpr = []
x = np.linspace(0,1,100)
cp_dict = {}
for pth in data.glob('*.csv'):
    df = pd.read_csv(pth)
    y=df['Diagnosis'].values
    pred=df['Prediction'].values
    #print(df['Patient_ID'].unique())
    fpr, tpr, _ = roc_curve(y, pred)
    interp_tpr.append(np.interp(x,xp=fpr,fp=tpr))
    roc_auc = auc(fpr, tpr)
    cp_dict[pth.stem] = roc_auc
    print(pth.stem, ':', roc_auc)
    AUC.append(roc_auc)
    plt.plot(fpr, tpr, color='darkorange',
             lw=lw -1, alpha = 0.3)

mean = np.mean(interp_tpr,axis=0)
std = np.std(interp_tpr,axis = 0)

plt.plot(x, mean , color = 'darkorange', lw=lw, label = 'AUC: {:.2f} ({:.2f}), best: {:.2}'.format(np.mean(AUC),np.std(AUC),np.max(AUC)))
plt.fill_between(x,mean + std, mean - std, alpha = 0.2, color = 'darkorange')    
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#plt.title('MJFF subject lvl 10-fold')
plt.legend(loc="lower right")
plt.savefig('MJFF_ENG_kfold.pdf')
plt.show()
# Out:
# fold_0 : 0.8887043189368771
# fold_1 : 0.633816425120773
# fold_2 : 0.5769230769230769
# fold_3 : 0.6866666666666666
# fold_4 : 0.7822222222222223
# fold_5 : 0.7432098765432099
# fold_6 : 0.9976190476190476
# fold_7 : 0.8200000000000001
# fold_8 : 0.9888888888888889
# fold_9 : 0.9336734693877551

# %%
cp_dict
# Out:
# {'fold_0': 0.8887043189368771,
#  'fold_1': 0.633816425120773,
#  'fold_2': 0.5769230769230769,
#  'fold_3': 0.6866666666666666,
#  'fold_4': 0.7822222222222223,
#  'fold_5': 0.7432098765432099,
#  'fold_6': 0.9976190476190476,
#  'fold_7': 0.8200000000000001,
#  'fold_8': 0.9888888888888889,
#  'fold_9': 0.9336734693877551}

# %%
data=Path(r'C:/Users/Mathias/repos/habitual_errors_NLP/results/MJFF/char_time/Spannish_talos_best_model_2020-04-04_06-08-53/SpanishData-preprocessed/')

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt

lw = 3
plt.figure(figsize = (5,5))
plt.axis('equal')
plt.grid(True, alpha = 0.3)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
AUC = []
interp_tpr = []
x = np.linspace(0,1,100)
for pth in data.glob('*.csv'):
    df = pd.read_csv(pth)
    y=df['Diagnosis'].values
    pred=df['Prediction'].values
    #print(df['Patient_ID'].unique())
    
    fpr, tpr, _ = roc_curve(y, pred)
    interp_tpr.append(np.interp(x,xp=fpr,fp=tpr))
    roc_auc = auc(fpr, tpr)
    AUC.append(roc_auc)
    plt.plot(fpr, tpr, color='darkorange',
             lw=lw -1, alpha = 0.3)

mean = np.mean(interp_tpr,axis=0)
std = np.std(interp_tpr,axis = 0)    
plt.plot(x, mean , color = 'darkorange', lw=lw, label = 'AUC: {:.2f} ({:.2f}), best: {:.2}'.format(np.mean(AUC),np.std(AUC),np.max(AUC)))
plt.fill_between(x,mean + std, mean - std, alpha = 0.2, color = 'darkorange')    
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#plt.title('MJFF SPANNISH participant lvl 9-fold')
plt.legend(loc="lower right")
plt.savefig('MJFF_SPANNISH_kfold.pdf')
plt.show()

# %%
data=Path(r'C:/Users/Mathias/repos/habitual_errors_NLP/results/MRC/char_time/MRCENG_talos_best_model_2020-04-05_07-25-31/EnglishData-preprocessed_attempt_1/')

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
from collections import  Counter

lw = 3
plt.figure(figsize = (5,5))
plt.axis('equal')
plt.grid(True, alpha = 0.3)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
AUC = []
interp_tpr = []
x = np.linspace(0,1,100)
for pth in data.glob('*.csv'):
    df = pd.read_csv(pth)
    y=df['Diagnosis'].values
    pred=df['Prediction'].values
    #print(df['Patient_ID'].unique())
    
    fpr, tpr, _ = roc_curve(y, pred)
    interp_tpr.append(np.interp(x,xp=fpr,fp=tpr))
    roc_auc = auc(fpr, tpr)
    AUC.append(roc_auc)
    plt.plot(fpr, tpr, color='darkorange',
             lw=lw -1, alpha = 0.3)
    
mean = np.mean(interp_tpr,axis=0)
std = np.std(interp_tpr,axis = 0)    
plt.plot(x, mean , color = 'darkorange', lw=lw, label = 'AUC: {:.2f} ({:.2f}), best: {:.2}'.format(np.mean(AUC),np.std(AUC),np.max(AUC)))
plt.fill_between(x,mean + std, mean - std, alpha = 0.2, color = 'darkorange')    
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#plt.title('MRC English participant lvl 10-fold')
plt.legend(loc="lower right")
plt.savefig('MRC_ENG_kfold.pdf')
plt.show()

# %%
data=Path(r'C:\Users\Mathias\repos\habitual_errors_NLP\results\MRC\char_time\MRCENG_LARGEBATCH_talos_best_model_2020-04-13_08-39-20\EnglishData-preprocessed_attempt_1')

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
from collections import  Counter

lw = 3
plt.figure(figsize = (5,5))
plt.axis('equal')
plt.grid(True, alpha = 0.3)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
AUC = []
interp_tpr = []
x = np.linspace(0,1,100)
for pth in data.glob('*.csv'):
    df = pd.read_csv(pth)
    y=df['Diagnosis'].values
    pred=df['Prediction'].values
    #print(df['Patient_ID'].unique())
    
    fpr, tpr, _ = roc_curve(y, pred)
    interp_tpr.append(np.interp(x,xp=fpr,fp=tpr))
    roc_auc = auc(fpr, tpr)
    AUC.append(roc_auc)
    plt.plot(fpr, tpr, color='darkorange',
             lw=lw -1, alpha = 0.3)
    
mean = np.mean(interp_tpr,axis=0)
std = np.std(interp_tpr,axis = 0)    
plt.plot(x, mean , color = 'darkorange', lw=lw, label = 'AUC: {:.2f} ({:.2f}), best: {:.2}'.format(np.mean(AUC),np.std(AUC),np.max(AUC)))
plt.fill_between(x,mean + std, mean - std, alpha = 0.2, color = 'darkorange')    
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#plt.title('MRC English participant lvl 10-fold')
plt.legend(loc="lower right")
plt.savefig('MRC_ENG_kfold.pdf')
plt.show()

# %%
df
# Out:
#     Unnamed: 0  round_epochs  val_loss  val_accuracy      loss  accuracy  \
# 0            0            64  0.693419      0.225410  0.693163  0.226542
# 1            1            39  0.694195      0.225410  0.693331  0.588388
# 2            2           129  0.691430      0.774590  0.693333  0.773458
# 3            3            57  0.808517      0.493852  0.681073  0.657335
# 4            4            75  0.693604      0.225410  0.693162  0.296008
# ..         ...           ...       ...           ...       ...       ...
# 81          81            56  0.690458      0.774590  0.693183  0.773458
# 82          82            74  0.693455      0.225410  0.693155  0.226542
# 83          83            46  1.437723      0.592213  0.437389  0.954899
# 84          84            65  0.693941      0.225410  0.693198  0.226542
# 85          85            73  0.752507      0.448770  0.706874  0.609642
#
#     alphabet_size  batch_size  bias_regularizer  control_class_weight  ...  \
# 0              60         256              0.07              0.646448  ...
# 1              60         128              0.04              0.646448  ...
# 2              60         128              0.04              0.646448  ...
# 3              60         256              0.07              0.646448  ...
# 4              60         256              0.07              0.646448  ...
# ..            ...         ...               ...                   ...  ...
# 81             60         128              0.01              0.646448  ...
# 82             60         256              0.01              0.646448  ...
# 83             60         256              0.04              0.646448  ...
# 84             60         256              0.01              0.646448  ...
# 85             60         256              0.04              0.646448  ...
#
#    last_activation                           loss.1 lr  max_sentence_length  \
# 0          softmax  sparse_categorical_crossentropy  1                11900
# 1          softmax  sparse_categorical_crossentropy  1                11900
# 2          softmax  sparse_categorical_crossentropy  1                11900
# 3          softmax  sparse_categorical_crossentropy  1                11900
# 4          softmax  sparse_categorical_crossentropy  1                11900
# ..             ...                              ... ..                  ...
# 81         softmax  sparse_categorical_crossentropy  1                11900
# 82         softmax  sparse_categorical_crossentropy  1                11900
# 83         softmax  sparse_categorical_crossentropy  1                11900
# 84         softmax  sparse_categorical_crossentropy  1                11900
# 85         softmax  sparse_categorical_crossentropy  1                11900
#
#    number_of_large_filters number_of_small_filters  \
# 0                        1                       3
# 1                        1                       3
# 2                        3                       1
# 3                        1                       1
# 4                        1                       3
# ..                     ...                     ...
# 81                       3                       3
# 82                       3                       3
# 83                       1                       1
# 84                       3                       1
# 85                       3                       1
#
#                           optimizer pd_class_weight  pool_length  \
# 0   <class 'keras.optimizers.Adam'>        2.207094            8
# 1   <class 'keras.optimizers.Adam'>        2.207094            4
# 2   <class 'keras.optimizers.Adam'>        2.207094            8
# 3   <class 'keras.optimizers.Adam'>        2.207094            8
# 4   <class 'keras.optimizers.Adam'>        2.207094            4
# ..                              ...             ...          ...
# 81  <class 'keras.optimizers.Adam'>        2.207094            8
# 82  <class 'keras.optimizers.Adam'>        2.207094            4
# 83  <class 'keras.optimizers.Adam'>        2.207094            8
# 84  <class 'keras.optimizers.Adam'>        2.207094            4
# 85  <class 'keras.optimizers.Adam'>        2.207094            8
#
#     small_filter_length
# 0                    16
# 1                    16
# 2                    16
# 3                     2
# 4                     2
# ..                  ...
# 81                   16
# 82                   16
# 83                   16
# 84                    2
# 85                   16
#
# [86 rows x 34 columns]
